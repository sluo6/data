# %%
import pandas as pd

# %%
pd.read_table(filepath_or_buffer="./original/20170529__Assay2_260nm_002.txt", header = 101, delimiter='\t', nrows=3001)
# Out:
#       R.Time (min)  Intensity
# 0          0.00000         -1
# 1          0.00833         -1
# 2          0.01667          0
# 3          0.02500          1
# 4          0.03333          1
# 5          0.04167          2
# 6          0.05000          2
# 7          0.05833          3
# 8          0.06667          3
# 9          0.07500          4
# 10         0.08333          3
# 11         0.09167          2
# 12         0.10000          1
# 13         0.10833          1
# 14         0.11667          1
# 15         0.12500          1
# 16         0.13333          1
# 17         0.14167          0
# 18         0.15000          0
# 19         0.15833          0
# 20         0.16667          0
# 21         0.17500          0
# 22         0.18333          1
# 23         0.19167          1
# 24         0.20000          1
# 25         0.20833          1
# 26         0.21667          1
# 27         0.22500          1
# 28         0.23333          2
# 29         0.24167          3
# ...

# %%
tocsv = pd.read_table(filepath_or_buffer="./original/20170529__Assay2_260nm_002.txt", header = 101, delimiter='\t', nrows=3001)

# %%
tocsv.to_csv("./original/Assay2_260nm_truncated", index = False, encoding = 'utf-8')
