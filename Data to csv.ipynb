# %%
import pandas as pd

# %%
pd.read_table(filepath_or_buffer="./original/20170529__Assay2_003.txt", header = 99, delimiter='\t', nrows=1201)
# Out:
#       R.Time (min)  Intensity
# 0          0.00000        -16
# 1          0.00833        -16
# 2          0.01667         -1
# 3          0.02500         -1
# 4          0.03333         -2
# 5          0.04167         -2
# 6          0.05000         -3
# 7          0.05833         -3
# 8          0.06667         -4
# 9          0.07500         -4
# 10         0.08333         -5
# 11         0.09167         -4
# 12         0.10000         -4
# 13         0.10833         -5
# 14         0.11667         -6
# 15         0.12500         -8
# 16         0.13333         -9
# 17         0.14167        -11
# 18         0.15000        -12
# 19         0.15833        -13
# 20         0.16667        -12
# 21         0.17500        -12
# 22         0.18333        -12
# 23         0.19167        -13
# 24         0.20000        -14
# 25         0.20833        -15
# 26         0.21667        -16
# 27         0.22500        -17
# 28         0.23333        -17
# 29         0.24167        -18
# ...

# %%
tocsv = pd.read_table(filepath_or_buffer="./original/20170529__Assay2_003.txt", header = 99, delimiter='\t', nrows=1201)

# %%
tocsv.to_csv("./original/Assay2_truncated", index = False, encoding = 'utf-8')
