# %%
import pandas as pd

# %%
pd.read_table(filepath_or_buffer="./original/20170529__Assay2+AMP_004.txt", header = 101, delimiter='\t', nrows=1201)
# Out:
#       R.Time (min)  Intensity
# 0          0.00000        -11
# 1          0.00833        -11
# 2          0.01667         -2
# 3          0.02500         -3
# 4          0.03333         -4
# 5          0.04167         -4
# 6          0.05000         -3
# 7          0.05833         -4
# 8          0.06667         -4
# 9          0.07500         -4
# 10         0.08333         -5
# 11         0.09167         -6
# 12         0.10000         -7
# 13         0.10833         -8
# 14         0.11667         -8
# 15         0.12500         -8
# 16         0.13333         -8
# 17         0.14167         -9
# 18         0.15000         -9
# 19         0.15833        -10
# 20         0.16667        -10
# 21         0.17500        -10
# 22         0.18333        -10
# 23         0.19167        -10
# 24         0.20000        -11
# 25         0.20833        -12
# 26         0.21667        -12
# 27         0.22500        -11
# 28         0.23333        -12
# 29         0.24167        -12
# ...

# %%
tocsv = pd.read_table(filepath_or_buffer="./original/20170529__Assay2+AMP_004.txt", header = 101, delimiter='\t', nrows=1201)

# %%
tocsv.to_csv("./original/Assay2_AMP_truncated", index = False, encoding = 'utf-8')
